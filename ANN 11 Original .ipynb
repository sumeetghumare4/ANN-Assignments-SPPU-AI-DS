# %% [markdown]
# ***11.MNIST Handwritten Character Detection using PyTorch, Keras and TensorFlow***

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models, optimizers
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()
x_train = x_train/255.0
x_test = x_test/255.0

# %%
model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer=optimizers.Adam(learning_rate=0.001),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=64, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2923 - accuracy: 0.9173
# Epoch 2/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1327 - accuracy: 0.9603
# Epoch 3/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0930 - accuracy: 0.9729
# Epoch 4/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0711 - accuracy: 0.9787
# Epoch 5/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0568 - accuracy: 0.9821
# Epoch 6/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0451 - accuracy: 0.9861
# Epoch 7/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0361 - accuracy: 0.9891
# Epoch 8/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0307 - accuracy: 0.9907
# Epoch 9/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0255 - accuracy: 0.9922
# Epoch 10/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0209 - accuracy: 0.9941

# %%
#df = keras.datasets.mnist.load_data()

plt.matshow(x_test[0])
plt.matshow(x_test[1])
plt.matshow(x_test[2])
plt.matshow(x_test[3])
plt.matshow(x_test[4])

# %%
y_predicted = model.predict(x_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
y_predicted_labels[:5]
# Out:
# 313/313 [==============================] - 1s 2ms/step
# [7, 2, 1, 0, 4]
